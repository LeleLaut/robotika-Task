# %% [markdown]
# #Convolutional Neural Network
# #####Alifia Mutiara Rahma_1103200025_Robotika

# %%
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip
# Out:
# --2023-12-23 16:36:24--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2023-12-23 16:36:25--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   319MB/s    in 0.2s
#
# 2023-12-23 16:36:25 (319 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
#ekstrak dataset
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
#melihat direktori dataset
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Bishop', 'Pawn', 'Knight', 'Queen', 'Rook', 'King']

# %%
#menghitung jumlah data pada tiap direktori
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
print('total bishop images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total queen images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total rook images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106
# total bishop images : 87
# total queen images : 78
# total rook images : 102

# %%
#melihat salah satu sample dataset
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
#import image generator dan mengaplikasikan augmentasi gambar
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.1) #set validation split

# %%
#membagi data training dan data testing menggunakan parameter subset 'training'/'validation'
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training'
) #set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, #direktori yang sama dengan data train
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
#arsitektur model 3 layer convolution dan 2 hidden layer; 512 dan 256 unit perseptron
import tensorflow as tf
model = tf.keras.models.Sequential([
    #input shape 150x150 pixel dan 3 bytes warna
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    #flatten the result to feed into a DNN
    tf.keras.layers.Flatten(),
    #512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    #output dengan 1 neuron
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
#optimizer dan loss
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 10s - loss: 1.8169 - accuracy: 0.1723 - val_loss: 1.7889 - val_accuracy: 0.1923 - 10s/epoch - 159ms/step
# Epoch 2/50
# 63/63 - 8s - loss: 1.7842 - accuracy: 0.1864 - val_loss: 1.7837 - val_accuracy: 0.1731 - 8s/epoch - 124ms/step
# Epoch 3/50
# 63/63 - 7s - loss: 1.7774 - accuracy: 0.2064 - val_loss: 1.7825 - val_accuracy: 0.2115 - 7s/epoch - 116ms/step
# Epoch 4/50
# 63/63 - 7s - loss: 1.7629 - accuracy: 0.2044 - val_loss: 1.7864 - val_accuracy: 0.1923 - 7s/epoch - 105ms/step
# Epoch 5/50
# 63/63 - 7s - loss: 1.7639 - accuracy: 0.2124 - val_loss: 1.7446 - val_accuracy: 0.2115 - 7s/epoch - 108ms/step
# Epoch 6/50
# 63/63 - 7s - loss: 1.7562 - accuracy: 0.2204 - val_loss: 1.7968 - val_accuracy: 0.1923 - 7s/epoch - 111ms/step
# Epoch 7/50
# 63/63 - 8s - loss: 1.7149 - accuracy: 0.2345 - val_loss: 1.7541 - val_accuracy: 0.2115 - 8s/epoch - 123ms/step
# Epoch 8/50
# 63/63 - 7s - loss: 1.6874 - accuracy: 0.2385 - val_loss: 1.7712 - val_accuracy: 0.2308 - 7s/epoch - 113ms/step
# Epoch 9/50
# 63/63 - 7s - loss: 1.7051 - accuracy: 0.2485 - val_loss: 1.7581 - val_accuracy: 0.1923 - 7s/epoch - 110ms/step
# Epoch 10/50
# 63/63 - 7s - loss: 1.6761 - accuracy: 0.2605 - val_loss: 1.7655 - val_accuracy: 0.2500 - 7s/epoch - 117ms/step
# Epoch 11/50
# 63/63 - 7s - loss: 1.6516 - accuracy: 0.3046 - val_loss: 1.7948 - val_accuracy: 0.1538 - 7s/epoch - 114ms/step
# Epoch 12/50
# 63/63 - 7s - loss: 1.6042 - accuracy: 0.3206 - val_loss: 1.6915 - val_accuracy: 0.3077 - 7s/epoch - 109ms/step
# Epoch 13/50
# 63/63 - 7s - loss: 1.5915 - accuracy: 0.3908 - val_loss: 1.6572 - val_accuracy: 0.3269 - 7s/epoch - 114ms/step
# Epoch 14/50
# 63/63 - 7s - loss: 1.5423 - accuracy: 0.3908 - val_loss: 1.6179 - val_accuracy: 0.3077 - 7s/epoch - 106ms/step
# Epoch 15/50
# 63/63 - 7s - loss: 1.4771 - accuracy: 0.4248 - val_loss: 1.5940 - val_accuracy: 0.4038 - 7s/epoch - 116ms/step
# Epoch 16/50
# 63/63 - 7s - loss: 1.4903 - accuracy: 0.3968 - val_loss: 1.6318 - val_accuracy: 0.3269 - 7s/epoch - 113ms/step
# Epoch 17/50
# 63/63 - 7s - loss: 1.3681 - accuracy: 0.4810 - val_loss: 1.6172 - val_accuracy: 0.3654 - 7s/epoch - 106ms/step
# Epoch 18/50
# 63/63 - 7s - loss: 1.3561 - accuracy: 0.4529 - val_loss: 1.5462 - val_accuracy: 0.3846 - 7s/epoch - 117ms/step
# Epoch 19/50
# 63/63 - 7s - loss: 1.2905 - accuracy: 0.4890 - val_loss: 1.4923 - val_accuracy: 0.3654 - 7s/epoch - 105ms/step
# Epoch 20/50
# 63/63 - 7s - loss: 1.2327 - accuracy: 0.5471 - val_loss: 1.4407 - val_accuracy: 0.4231 - 7s/epoch - 105ms/step
# Epoch 21/50
# 63/63 - 7s - loss: 1.2393 - accuracy: 0.5090 - val_loss: 1.4502 - val_accuracy: 0.5192 - 7s/epoch - 107ms/step
# Epoch 22/50
# 63/63 - 7s - loss: 1.2086 - accuracy: 0.5251 - val_loss: 1.4344 - val_accuracy: 0.3462 - 7s/epoch - 119ms/step
# Epoch 23/50
# 63/63 - 7s - loss: 1.1294 - accuracy: 0.5852 - val_loss: 1.5308 - val_accuracy: 0.3846 - 7s/epoch - 105ms/step
# Epoch 24/50
# 63/63 - 7s - loss: 1.1315 - accuracy: 0.5711 - val_loss: 1.3734 - val_accuracy: 0.4038 - 7s/epoch - 104ms/step
# Epoch 25/50
# 63/63 - 7s - loss: 1.0625 - accuracy: 0.6232 - val_loss: 1.2659 - val_accuracy: 0.4808 - 7s/epoch - 106ms/step
# Epoch 26/50
# 63/63 - 7s - loss: 1.0232 - accuracy: 0.6212 - val_loss: 1.3738 - val_accuracy: 0.5000 - 7s/epoch - 115ms/step
# Epoch 27/50
# 63/63 - 7s - loss: 0.9573 - accuracy: 0.6553 - val_loss: 1.4194 - val_accuracy: 0.5000 - 7s/epoch - 116ms/step
# Epoch 28/50
# 63/63 - 7s - loss: 0.9379 - accuracy: 0.6593 - val_loss: 1.5278 - val_accuracy: 0.4615 - 7s/epoch - 106ms/step
# Epoch 29/50
# 63/63 - 7s - loss: 0.9109 - accuracy: 0.6673 - val_loss: 1.3738 - val_accuracy: 0.4038 - 7s/epoch - 103ms/step
# Epoch 30/50
# 63/63 - 7s - loss: 0.8374 - accuracy: 0.6653 - val_loss: 1.4408 - val_accuracy: 0.4808 - 7s/epoch - 104ms/step
# Epoch 31/50
# 63/63 - 7s - loss: 0.8385 - accuracy: 0.6874 - val_loss: 1.4491 - val_accuracy: 0.3846 - 7s/epoch - 116ms/step
# Epoch 32/50
# 63/63 - 7s - loss: 0.8608 - accuracy: 0.6794 - val_loss: 1.3722 - val_accuracy: 0.4038 - 7s/epoch - 118ms/step
# Epoch 33/50
# 63/63 - 7s - loss: 0.8225 - accuracy: 0.7275 - val_loss: 1.3965 - val_accuracy: 0.4423 - 7s/epoch - 116ms/step
# Epoch 34/50
# 63/63 - 7s - loss: 0.6751 - accuracy: 0.7395 - val_loss: 1.2526 - val_accuracy: 0.5385 - 7s/epoch - 108ms/step
# Epoch 35/50
# 63/63 - 7s - loss: 0.6654 - accuracy: 0.7335 - val_loss: 1.3605 - val_accuracy: 0.5192 - 7s/epoch - 114ms/step
# Epoch 36/50
# 63/63 - 7s - loss: 0.7364 - accuracy: 0.7295 - val_loss: 1.2447 - val_accuracy: 0.4808 - 7s/epoch - 118ms/step
# Epoch 37/50
# 63/63 - 7s - loss: 0.6273 - accuracy: 0.7635 - val_loss: 1.3761 - val_accuracy: 0.4423 - 7s/epoch - 113ms/step
# Epoch 38/50
# 63/63 - 7s - loss: 0.6738 - accuracy: 0.7555 - val_loss: 1.2137 - val_accuracy: 0.5000 - 7s/epoch - 106ms/step
# Epoch 39/50
# 63/63 - 7s - loss: 0.5512 - accuracy: 0.7976 - val_loss: 1.6566 - val_accuracy: 0.5000 - 7s/epoch - 105ms/step
# Epoch 40/50
# 63/63 - 7s - loss: 0.5879 - accuracy: 0.7996 - val_loss: 1.3080 - val_accuracy: 0.5000 - 7s/epoch - 116ms/step
# Epoch 41/50
# 63/63 - 7s - loss: 0.5280 - accuracy: 0.8136 - val_loss: 1.2883 - val_accuracy: 0.5577 - 7s/epoch - 112ms/step
# Epoch 42/50
# 63/63 - 7s - loss: 0.5558 - accuracy: 0.7896 - val_loss: 1.1604 - val_accuracy: 0.5385 - 7s/epoch - 106ms/step
# Epoch 43/50
# 63/63 - 7s - loss: 0.5474 - accuracy: 0.8076 - val_loss: 1.6438 - val_accuracy: 0.5000 - 7s/epoch - 117ms/step
# Epoch 44/50
# 63/63 - 8s - loss: 0.5655 - accuracy: 0.7976 - val_loss: 1.4333 - val_accuracy: 0.4231 - 8s/epoch - 126ms/step
# Epoch 45/50
# 63/63 - 7s - loss: 0.4492 - accuracy: 0.8317 - val_loss: 1.3378 - val_accuracy: 0.4423 - 7s/epoch - 112ms/step
# Epoch 46/50
# 63/63 - 7s - loss: 0.5071 - accuracy: 0.8236 - val_loss: 1.1538 - val_accuracy: 0.5962 - 7s/epoch - 109ms/step
# Epoch 47/50
# 63/63 - 7s - loss: 0.4860 - accuracy: 0.8337 - val_loss: 1.2402 - val_accuracy: 0.5577 - 7s/epoch - 116ms/step
# Epoch 48/50
# 63/63 - 7s - loss: 0.5009 - accuracy: 0.8397 - val_loss: 1.3521 - val_accuracy: 0.4615 - 7s/epoch - 116ms/step
# Epoch 49/50
# 63/63 - 7s - loss: 0.4973 - accuracy: 0.8397 - val_loss: 1.4930 - val_accuracy: 0.4615 - 7s/epoch - 103ms/step
# Epoch 50/50
# 63/63 - 7s - loss: 0.4769 - accuracy: 0.8357 - val_loss: 1.2663 - val_accuracy: 0.4423 - 7s/epoch - 109ms/step

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ##Arsitektur Baru dari ChatGPT

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
#from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    BatchNormalization(),
    MaxPooling2D(2, 2),

    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.4),

    Flatten(),

    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(6, activation='softmax')
])

# Adding Early Stopping callback
#early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    train_generator,
    epochs=50,  # You can adjust the number of epochs
    validation_data=validation_generator,
    #callbacks=[early_stopping]  # Include the Early Stopping callback
)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 12s 134ms/step - loss: 2.8120 - accuracy: 0.1864 - val_loss: 4.1275 - val_accuracy: 0.1346
# Epoch 2/50
# 63/63 [==============================] - 7s 111ms/step - loss: 2.7893 - accuracy: 0.1844 - val_loss: 4.2219 - val_accuracy: 0.1346
# Epoch 3/50
# 63/63 [==============================] - 8s 128ms/step - loss: 2.3843 - accuracy: 0.2144 - val_loss: 3.7439 - val_accuracy: 0.1538
# Epoch 4/50
# 63/63 [==============================] - 8s 121ms/step - loss: 2.3561 - accuracy: 0.1984 - val_loss: 2.4490 - val_accuracy: 0.2308
# Epoch 5/50
# 63/63 [==============================] - 7s 109ms/step - loss: 2.2990 - accuracy: 0.2204 - val_loss: 2.2973 - val_accuracy: 0.2500
# Epoch 6/50
# 63/63 [==============================] - 8s 128ms/step - loss: 2.2283 - accuracy: 0.2104 - val_loss: 1.9979 - val_accuracy: 0.2308
# Epoch 7/50
# 63/63 [==============================] - 7s 116ms/step - loss: 2.2058 - accuracy: 0.2325 - val_loss: 1.8294 - val_accuracy: 0.2500
# Epoch 8/50
# 63/63 [==============================] - 7s 112ms/step - loss: 2.0563 - accuracy: 0.2465 - val_loss: 1.7777 - val_accuracy: 0.1731
# Epoch 9/50
# 63/63 [==============================] - 8s 129ms/step - loss: 2.1182 - accuracy: 0.2505 - val_loss: 1.7674 - val_accuracy: 0.2692
# Epoch 10/50
# 63/63 [==============================] - 8s 122ms/step - loss: 2.0789 - accuracy: 0.2365 - val_loss: 1.7778 - val_accuracy: 0.1731
# Epoch 11/50
# 63/63 [==============================] - 7s 112ms/step - loss: 1.9396 - accuracy: 0.2766 - val_loss: 1.7619 - val_accuracy: 0.2500
# Epoch 12/50
# 63/63 [==============================] - 7s 111ms/step - loss: 1.9975 - accuracy: 0.2345 - val_loss: 1.7639 - val_accuracy: 0.2885
# Epoch 13/50
# 63/63 [==============================] - 9s 147ms/step - loss: 1.9215 - accuracy: 0.2625 - val_loss: 1.8957 - val_accuracy: 0.2308
# Epoch 14/50
# 63/63 [==============================] - 8s 130ms/step - loss: 1.8912 - accuracy: 0.2545 - val_loss: 1.7927 - val_accuracy: 0.2692
# Epoch 15/50
# 63/63 [==============================] - 7s 113ms/step - loss: 1.8575 - accuracy: 0.2725 - val_loss: 1.8861 - val_accuracy: 0.2308
# Epoch 16/50
# 63/63 [==============================] - 7s 111ms/step - loss: 1.9356 - accuracy: 0.2745 - val_loss: 1.7865 - val_accuracy: 0.2500
# Epoch 17/50
# 63/63 [==============================] - 8s 132ms/step - loss: 1.8391 - accuracy: 0.2465 - val_loss: 1.7465 - val_accuracy: 0.2115
# Epoch 18/50
# 63/63 [==============================] - 8s 121ms/step - loss: 1.9193 - accuracy: 0.2625 - val_loss: 2.6732 - val_accuracy: 0.1731
# Epoch 19/50
# 63/63 [==============================] - 7s 117ms/step - loss: 1.7653 - accuracy: 0.2766 - val_loss: 1.7451 - val_accuracy: 0.2692
# Epoch 20/50
# 63/63 [==============================] - 8s 129ms/step - loss: 1.7772 - accuracy: 0.2745 - val_loss: 1.6738 - val_accuracy: 0.3462
# Epoch 21/50
# 63/63 [==============================] - 7s 109ms/step - loss: 1.7733 - accuracy: 0.2826 - val_loss: 1.7221 - val_accuracy: 0.3269
# Epoch 22/50
# 63/63 [==============================] - 7s 114ms/step - loss: 1.7850 - accuracy: 0.2705 - val_loss: 1.8027 - val_accuracy: 0.3462
# Epoch 23/50
# 63/63 [==============================] - 9s 139ms/step - loss: 1.7732 - accuracy: 0.2946 - val_loss: 1.8983 - val_accuracy: 0.2500
# Epoch 24/50
# 63/63 [==============================] - 7s 111ms/step - loss: 1.7558 - accuracy: 0.2786 - val_loss: 1.9865 - val_accuracy: 0.2308
# Epoch 25/50
# 63/63 [==============================] - 8s 130ms/step - loss: 1.7235 - accuracy: 0.3246 - val_loss: 1.6849 - val_accuracy: 0.3077
# Epoch 26/50
# 63/63 [==============================] - 8s 127ms/step - loss: 1.7132 - accuracy: 0.2766 - val_loss: 1.7635 - val_accuracy: 0.2885
# Epoch 27/50
# 63/63 [==============================] - 8s 122ms/step - loss: 1.7031 - accuracy: 0.3287 - val_loss: 1.7335 - val_accuracy: 0.2692
# Epoch 28/50
# 63/63 [==============================] - 7s 113ms/step - loss: 1.6794 - accuracy: 0.3307 - val_loss: 1.8360 - val_accuracy: 0.1346
# Epoch 29/50
# 63/63 [==============================] - 8s 127ms/step - loss: 1.7104 - accuracy: 0.3026 - val_loss: 1.6003 - val_accuracy: 0.3269
# Epoch 30/50
# 63/63 [==============================] - 8s 127ms/step - loss: 1.6471 - accuracy: 0.3267 - val_loss: 1.5164 - val_accuracy: 0.3654
# Epoch 31/50
# 63/63 [==============================] - 7s 110ms/step - loss: 1.6558 - accuracy: 0.3226 - val_loss: 1.6496 - val_accuracy: 0.2885
# Epoch 32/50
# 63/63 [==============================] - 8s 130ms/step - loss: 1.6619 - accuracy: 0.3287 - val_loss: 1.6063 - val_accuracy: 0.3654
# Epoch 33/50
# 63/63 [==============================] - 8s 121ms/step - loss: 1.6377 - accuracy: 0.3447 - val_loss: 1.7028 - val_accuracy: 0.3269
# Epoch 34/50
# 63/63 [==============================] - 7s 112ms/step - loss: 1.6406 - accuracy: 0.3447 - val_loss: 1.7779 - val_accuracy: 0.1923
# Epoch 35/50
# 63/63 [==============================] - 7s 112ms/step - loss: 1.6294 - accuracy: 0.3327 - val_loss: 1.6805 - val_accuracy: 0.2308
# Epoch 36/50
# 63/63 [==============================] - 8s 129ms/step - loss: 1.6216 - accuracy: 0.3246 - val_loss: 1.7813 - val_accuracy: 0.2692
# Epoch 37/50
# 63/63 [==============================] - 8s 123ms/step - loss: 1.6360 - accuracy: 0.3267 - val_loss: 1.6224 - val_accuracy: 0.3269
# Epoch 38/50
# 63/63 [==============================] - 7s 113ms/step - loss: 1.5212 - accuracy: 0.3788 - val_loss: 1.5667 - val_accuracy: 0.3077
# Epoch 39/50
# 63/63 [==============================] - 8s 128ms/step - loss: 1.6149 - accuracy: 0.3487 - val_loss: 1.8519 - val_accuracy: 0.3462
# Epoch 40/50
# 63/63 [==============================] - 8s 131ms/step - loss: 1.5765 - accuracy: 0.3667 - val_loss: 1.6956 - val_accuracy: 0.2115
# Epoch 41/50
# 63/63 [==============================] - 7s 118ms/step - loss: 1.5673 - accuracy: 0.3667 - val_loss: 1.6010 - val_accuracy: 0.3269
# Epoch 42/50
# 63/63 [==============================] - 7s 111ms/step - loss: 1.5164 - accuracy: 0.3928 - val_loss: 1.5577 - val_accuracy: 0.3654
# Epoch 43/50
# 63/63 [==============================] - 7s 111ms/step - loss: 1.5201 - accuracy: 0.4168 - val_loss: 1.7686 - val_accuracy: 0.3077
# Epoch 44/50
# 63/63 [==============================] - 8s 131ms/step - loss: 1.4725 - accuracy: 0.3948 - val_loss: 1.4879 - val_accuracy: 0.3654
# Epoch 45/50
# 63/63 [==============================] - 8s 120ms/step - loss: 1.5253 - accuracy: 0.3908 - val_loss: 1.7902 - val_accuracy: 0.2692
# Epoch 46/50
# 63/63 [==============================] - 7s 115ms/step - loss: 1.7399 - accuracy: 0.3146 - val_loss: 1.7424 - val_accuracy: 0.2115
# Epoch 47/50
# 63/63 [==============================] - 8s 130ms/step - loss: 1.6387 - accuracy: 0.3206 - val_loss: 1.5523 - val_accuracy: 0.3462
# Epoch 48/50
# 63/63 [==============================] - 7s 110ms/step - loss: 1.6487 - accuracy: 0.3106 - val_loss: 1.8224 - val_accuracy: 0.2308
# Epoch 49/50
# 63/63 [==============================] - 8s 129ms/step - loss: 1.5095 - accuracy: 0.3988 - val_loss: 1.6934 - val_accuracy: 0.3462
# Epoch 50/50
# 63/63 [==============================] - 7s 117ms/step - loss: 1.4790 - accuracy: 0.4228 - val_loss: 1.5706 - val_accuracy: 0.4423

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
